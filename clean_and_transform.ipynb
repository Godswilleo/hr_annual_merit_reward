# %% [markdown]
# # Cleaning and Transforming the Dataset for the Reward

# %%
# importing the needed library
import pandas as pd

# %%
employee = pd.read_csv("employee_performance_full.csv", sep=",")

# %%
# Checking out the columns contained in the dataset 
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Staff_Id                  1029 non-null   object
#  1   Age                       924 non-null    float64
#  2   Attrition                 1029 non-null   object
#  3   BusinessTravel            1024 non-null   object
#  4   DailyRate                 1002 non-null   float64
#  5   Department                1029 non-null   object
#  6   DistanceFromHome          1029 non-null   int64
#  7   Education                 1029 non-null   int64
#  8   EducationField            1029 non-null   object
#  9   EmployeeNumber            1029 non-null   int64
#  10  EnvironmentSatisfaction   1029 non-null   int64
#  11  Gender                    1029 non-null   object
#  12  JobInvolvement            1029 non-null   int64
#  13  JobLevel                  1029 non-null   int64
#  14  JobRole                   1029 non-null   object
#  15  JobSatisfaction           1029 non-null   int64
#  16  MaritalStatus             1029 non-null   object
#  17  MonthlySalary             1029 non-null   int64
#  18  NumCompaniesWorked        1029 non-null   int64
#  19  Over18                    1029 non-null   object
#  20  OverTime                  1029 non-null   object
#  21  PercentSalaryHike         1029 non-null   int64
#  22  PerformanceRating         1029 non-null   int64
#  23  RelationshipSatisfaction  1029 non-null   int64
#  24  StandardHours             1029 non-null   int64
#  25  StockOptionLevel          1029 non-null   int64
#  26  TotalWorkingYears         1029 non-null   int64
#  27  TrainingTimesLastYear     1029 non-null   int64
#  28  WorkLifeBalance           1029 non-null   int64
#  29  YearsAtCompany            1029 non-null   int64
#  30  YearsInCurrentRole        1029 non-null   int64
#  31  YearsSinceLastPromotion   1029 non-null   int64
#  32  YearsWithCurrManager      1029 non-null   int64
#  33  Quarter1_KPI_Score        1029 non-null   int64
#  34  Quarter2_KPI_Score        1029 non-null   int64
#  35  Quarter3_KPI_Score        1029 non-null   int64
#  36  Quarter4_KPI_Score        1029 non-null   int64
# dtypes: float64(2), int64(25), object(10)
# memory usage: 297.6+ KB

# %%
employee.sample(5)
# Out:
#     Staff_Id   Age Attrition     BusinessTravel  DailyRate  \
# 589  SN00590  29.0       Yes  Travel_Frequently      746.0
# 658  SN00659  34.0        No         Non-Travel     1065.0
# 681  SN00682  31.0        No  Travel_Frequently      853.0
# 734  SN00735  29.0        No  Travel_Frequently      410.0
# 865  SN00866  49.0        No      Travel_Rarely     1313.0
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 589                   Sales                24          3  Technical Degree
# 658                   Sales                23          4         Marketing
# 681  Research & Development                 1          1     Life Sciences
# 734  Research & Development                 2          1     Life Sciences
# 865                   Sales                11          4         Marketing
#
#      EmployeeNumber  ...  TrainingTimesLastYear WorkLifeBalance  \
# 589            1928  ...                      3               3
# 658              60  ...                      2               3
# 681            1011  ...                      1               3
# 734            1513  ...                      3               3
# 865            1757  ...                      1               4
#
#      YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 589               1                   0                       0
# 658               9                   5                       8
# 681               4                   3                       0
# 734               3                   2                       0
# 865               5                   1                       0
#
#      YearsWithCurrManager Quarter1_KPI_Score  Quarter2_KPI_Score  \
# 589                     0                  0                   0
# 658                     7                 61                  41
# 681                     3                 47                  29
# 734                     2                 66                  43
# 865                     4                 51                  26
#
#      Quarter3_KPI_Score Quarter4_KPI_Score
# 589                   0                  0
# 658                  63                 61
# 681                  60                 59
# 734                  73                 63
# 865                  58                 56
#
# [5 rows x 37 columns]

# %%
pd.value_counts(employee['Attrition'])
# Out:
# No     853
# Yes    176
# Name: Attrition, dtype: int64

# %% [markdown]
# 176 staff are no more with the organization

# %%
# checking for duplicates
sum(current_employee.duplicated())
# Out:
# 0

# %% [markdown]
# There are no duplicate records

# %%
current_employee.isna().sum()
# Out:
# Staff_Id                      0
# Age                         105
# BusinessTravel                5
# DailyRate                    24
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlySalary                 0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# YearsAtCompany                0
# YearsInCurrentRole            0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# Quarter1_KPI_Score            0
# Quarter2_KPI_Score            0
# Quarter3_KPI_Score            0
# Quarter4_KPI_Score            0
# dtype: int64

# %% [markdown]
# ## Issues with the Dataset

# %% [markdown]
# 1. It can be seen that there is an **Attrition** column. This column has just two unique values Yes and No. It is **Yes** for cases where the staff has left the organization and **No** in cases were the staff is still with the organization.176 member staff have left the organization.This project is mearnt to focus on only staff who are still in the organization. Hence staff who have left the organization should be removed

# %% [markdown]
# ## Cleaning up the Data

# %% [markdown]
# #### Operation
# To filter out only the staff who are currently in the organization

# %% [markdown]
# #### Code

# %%
# filtering out only current staff
current_employee = employee[employee['Attrition'] == 'No']

# %% [markdown]
# #### Test

# %%
current_employee.sample(10)
# Out:
#     Staff_Id   Age Attrition     BusinessTravel  DailyRate  \
# 832  SN00833   NaN        No      Travel_Rarely      528.0
# 672  SN00673  40.0        No  Travel_Frequently      593.0
# 631  SN00632  31.0        No      Travel_Rarely      196.0
# 707  SN00708  19.0        No      Travel_Rarely      645.0
# 276  SN00277  31.0        No      Travel_Rarely     1274.0
# 777  SN00778   NaN        No      Travel_Rarely      185.0
# 133  SN00134  38.0        No      Travel_Rarely      168.0
# 613  SN00614  46.0        No      Travel_Rarely      228.0
# 100  SN00101  32.0        No  Travel_Frequently     1311.0
# 570  SN00571  30.0        No         Non-Travel     1400.0
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 832         Human Resources                 8          4  Technical Degree
# 672  Research & Development                 9          4           Medical
# 631                   Sales                29          4         Marketing
# 707  Research & Development                 9          2     Life Sciences
# 276  Research & Development                 9          1     Life Sciences
# 777  Research & Development                23          4           Medical
# 133  Research & Development                 1          3     Life Sciences
# 613                   Sales                 0          3     Life Sciences
# 100  Research & Development                 7          3     Life Sciences
# 570  Research & Development                 0          3     Life Sciences
#
#      EmployeeNumber  ...  TrainingTimesLastYear WorkLifeBalance  \
# 832            1164  ...                      2               1
# 672            1166  ...                      3               2
# 631            1784  ...                      3               3
# 707            1193  ...                      4               3
# 276             581  ...                      6               4
# 777            1826  ...                      2               4
# 133             743  ...                      4               4
# 613            1527  ...                      2               4
# 100             359  ...                      3               1
# 570             562  ...                      3               1
#
#      YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 832               5                   4                       1
# 672              18                   7                       2
# 631              12                   7                       5
# 707               1                   1                       0
# 276              13                   8                       0
# 777               5                   4                       0
# 133               1                   0                       0
# 613              13                  12                       5
# 100               5                   1                       0
# 570               5                   3                       1
#
#      YearsWithCurrManager Quarter1_KPI_Score  Quarter2_KPI_Score  \
# 832                     4                 58                  40
# 672                    13                 68                  44
# 631                     7                 65                  44
# 707                     0                 66                  48
# 276                     8                 70                  50
# 777                     3                 57                  39
# 133                     0                 61                  49
# 613                     1                 50                  30
# 100                     3                 59                  47
# 570                     4                 62                  43
#
#      Quarter3_KPI_Score Quarter4_KPI_Score
# 832                  61                 61
# 672                  70                 71
# 631                  66                 67
# 707                  78                 81
# 276                  83                 82
# 777                  65                 59
# 133                  73                 75
# 613                  59                 61
# 100                  71                 68
# 570                  66                 68
#
# [10 rows x 37 columns]

# %%
pd.value_counts(current_employee['Attrition'])
# Out:
# No    853
# Name: Attrition, dtype: int64

# %% [markdown]
# The **current_employee** dataset now contain records of only current staff

# %%
## dropping the Attrition column
current_employee.drop('Attrition', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9824\895533546.py in <module>
#       1 ## dropping the Attrition column
# ----> 2 current_employee.drop('Attrition', axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['Attrition'] not found in axis"

# %% [markdown]
# ## Creating the new CSV

# %%
# Saving the current_employee dataset as the working csv file
current_employee.to_csv('employee_attrition_train.csv', index=False)
